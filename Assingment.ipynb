# %%
''''Ans 1.
        Guido van Rossum and was first released in 1991.
    
    Ans 2.
        Object-Oriented Programming (OOP)
        Functional Programming
        Imperative Programming
        Procedural Programming
        
    Ans 3.
        Yes
        
    Ans 4.
        .py
        
    Ans 5.
        Interpreted
    
    Ans 6.
        if
        for loop
        while loop
        Function
        class
        
    Ans 7.
        #
        
    Ans 8.
        import sys
        print(sys.version)
        
    Ans 9.
        lambda fuction
        lambda key word use 
        
    Ans 10.
        preferred installer program
        
    Ans 11.
        .append()
        del
        .upper()
        .lower()
        .casefold()
        .update()
        .remove()
        .sort()
        .count()
        
    Ans 12.
        In Python, there is no specific maximum length for an identifier
        
    Ans 13.
        Benifit of Python:
        ->Simple and Easy language
        ->Versatile
        ->Dynamic Typing
        ->Large library
        ->USE in ---Machine Learning
                    Data Science
                    Game Devlopment
                    Web Devlopement
                    AI         etc....
        ->Readable code
        ->OPP Concept
        
    Ans 14.
        Memory management in Python is done automatically by the Python memory manager
        Object Reference Counting :
                                    Python keeps track of the number of references to each object in memory
                                    , and frees memory when the number of references drops to zero.
        Garbage Collection
        Dynamic Memory Allocation
        
    Ans 15.
      - Download the latest version of Python from the official website (https://www.python.org/downloads/).
      -Run the installer and follow the on-screen instructions to complete the installation process.
      -Open the Start menu and search for "Environment Variables" and select "Edit the system environment variables".
      - In the System Properties window, click on the "Environment Variables" button.
      - Under "System Variables", scroll down and find the "Path" variable, then click "Edit".
      -Click "New" and add the path to the Python installation (e.g., "C:\Python37").
      - Click "OK" to close all the windows.
       
       After following these steps, you should be able to run Python from the command prompt. To test it, open the Command Prompt and type "python" to start the Python interpreter.
        
    Ans 16.
        Yes
